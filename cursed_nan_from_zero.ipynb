# %%
import jax
jax.config.update('jax_default_device',jax.devices()[-1])
import equinox as eqx
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
from jax import grad, vmap
import optax
from diffrax import diffeqsolve, ODETerm, Dopri5, ControlTerm, Euler, MultiTerm, ODETerm, SaveAt, VirtualBrownianTree, Heun

# %% [markdown]
# #### Stochastic interpolants example (SDE)

# %%
num_target = 5000
key = jax.random.PRNGKey(10)
target_samples = jax.random.uniform(key,shape = (10*num_target,2),minval=-1,maxval=1)
target_samples = 8 * target_samples[jnp.sum(jnp.abs(target_samples),1)>1.][:num_target]

num_reference = 10000
key = jax.random.PRNGKey(15)
reference_samples = jax.random.normal(key=key,shape=(num_reference,2))
plt.scatter(target_samples[:,0],target_samples[:,1])

# %%
class NeuralNetwork(eqx.Module):
    layers: list
    extra_bias: jax.Array

    def __init__(self, key):
        key1, key2, key3,key4 = jax.random.split(key, 4)
        # These contain trainable parameters.

        num_params_per_layer  = 256
        self.layers = [eqx.nn.Linear(3, num_params_per_layer, key=key1),
                       jax.nn.elu,
                       eqx.nn.Linear(num_params_per_layer, num_params_per_layer, key=key2),
                       jax.nn.elu,
                       eqx.nn.Linear(num_params_per_layer, num_params_per_layer, key=key3),
                       jax.nn.elu,
                       eqx.nn.Linear(num_params_per_layer, 2, key=key4)]
        # This is also a trainable parameter.
        self.extra_bias = jax.numpy.ones(2)

    def __call__(self, x):
        for layer in self.layers[:-1]:
            x = jax.nn.relu(layer(x))
        return self.layers[-1](x) + self.extra_bias
    
def I(t,x,y):
    return jnp.cos(t)*x + jnp.sin(t)*y

def It(t,x,y):
    return -jnp.sin(t)*x + jnp.cos(t)*y

def gamma(t):
    return jnp.sqrt(2*t*(1-t))

gammadot = vmap(vmap(grad(gamma)))


@eqx.filter_jit  # compile this function to make it run fast.
# @eqx.filter_grad  # differentiate all floating-point arrays in `model`.
def loss(b_model, t, x, y, z):
    tx = jnp.hstack([t.reshape(-1,1),I(t,x,y)+gamma(t)*z])
    bhat = jax.vmap(b_model)(tx)  # vectorise the model over a batch of data


    bnorm2 = jnp.mean(jnp.sum(bhat**2,axis=1))
    dot_term = jnp.mean(jnp.sum((It(t,x,y) + gammadot(t)*z)*bhat,axis=1))
#     dot_term = 2 * jnp.mean(jnp.sum((It(t,x,y))*bhat,axis=1))
    return bnorm2 - 2*dot_term
    # return jnp.mean((bhat - (It(t,x,y) + gammadot(t)*z))**2)

def loss_denoise(eta_model,t,x,y,z):
    tx = jnp.hstack([t.reshape(-1,1),I(t,x,y)+gamma(t)*z])
    etahat = jax.vmap(eta_model)(tx)  # vectorise the model over a batch of data
    
    etanorm2 = jnp.mean(jnp.sum(etahat**2,axis=1))
    dot_term = jnp.mean(jnp.sum(etahat*z,axis=1))
    return etanorm2 - 2*dot_term

# %%
# t = jax.random.uniform(jax.random.PRNGKey(3),(num_target,1))
# z = jax.random.normal(jax.random.PRNGKey(4),(num_target,2))
# model = NeuralNetwork(jax.random.PRNGKey(0))
# loss(model,t,reference_samples,target_samples,z)
# loss_denoise(model,t,reference_samples,target_samples,z)

# %%
def evaluate_b(b_model, testloader):
    avg_loss = 0
    for t,x,y,z in testloader:
        avg_loss += loss(b_model,t,x,y,z)
    return avg_loss / 100

def evaluate_eta(eta_model, testloader):
    avg_loss = 0
    for t,x,y,z in testloader:
        avg_loss += loss_denoise(eta_model,t,x,y,z)
    return avg_loss / 100

# %%
def get_trainloader(batch_size = 512):
    batch_num = 0
    while True:
        batch_num+=1
        trainloader_key = jax.random.PRNGKey(batch_num)
        ref_key,target_key,normal_key,t_key = jax.random.split(trainloader_key,4)

        ref_batch = jax.random.choice(ref_key,reference_samples,(batch_size,))
        target_batch = jax.random.choice(target_key,target_samples,(batch_size,))

        t_vals = jax.random.uniform(t_key,(batch_size,1))

        z = jax.random.normal(normal_key,ref_batch.shape)

        yield t_vals,ref_batch,target_batch,z

def get_testloader(batch_size = 1000):
    num_batches = 100
    for i in range(num_batches):
        testloader_key = jax.random.PRNGKey(1000*i)
        ref_key,target_key,normal_key,t_key = jax.random.split(testloader_key,4)

        ref_batch = jax.random.choice(ref_key,reference_samples,(batch_size,))
        target_batch = jax.random.choice(target_key,target_samples,(batch_size,))

        t_vals = jax.random.uniform(t_key,(batch_size,1))

        z = jax.random.normal(normal_key,ref_batch.shape)
        yield t_vals,ref_batch,target_batch,z

# %%
def train_eta(
  model: NeuralNetwork,
  optim,
  steps,
  train_loader,
  print_every,
)  -> NeuralNetwork:
    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    @eqx.filter_jit
    def make_step(
        model,
        opt_state,
        t,
        x,
        y,
        z
    ):
        loss_value, grads = eqx.filter_value_and_grad(loss_denoise)(model,t,x,y,z)
        updates, opt_state = optim.update(grads,opt_state,model)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss_value
    train_losses = []
    
    for step, (t,x,y,z) in zip(range(steps), train_loader):
        model, opt_state, train_loss = make_step(model, opt_state, t,x,y,z)
        train_losses.append(train_loss)
        if jnp.isnan(train_loss):
            print("Nan")
            break
        if (step % print_every) == 0 or (step == steps - 1):
            testloader = get_testloader()
            test_loss = evaluate_eta(model, testloader)
            print("step=" + str(step) + " | train_loss=" + str(train_loss) + " | test_loss= "+ str(test_loss))

    return model,train_losses

def train_b(
  model: NeuralNetwork,
  optim,
  steps,
  train_loader,
  print_every,
)  -> NeuralNetwork:
    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    #@eqx.filter_jit
    def make_step(
        model,
        opt_state,
        t,
        x,
        y,
        z
    ):
        loss_value, grads = eqx.filter_value_and_grad(loss)(model,t,x,y,z)
        if jnp.isnan(grads.layers[0].weight).any():
            print(grads.layers[0].weight[0][:10])
            tx = jnp.hstack([t.reshape(-1,1),I(t,x,y)+gamma(t)*z])

            print("Any nans predicted?")
            print(jnp.isnan(jax.vmap(model)(tx)).any())
            print("Loss value")
            inds = range(0,len(t))
            loss_sub_batches = jnp.array([
                loss(model,t[lower:lower+1],x[lower:lower+1],y[lower:lower+1],z[lower:lower+1]) for lower in inds
            ])
            bad_batches = jnp.isnan(loss_sub_batches)
            print('t',t[bad_batches])
            print('x',x[bad_batches])
            print('y',y[bad_batches])
            print('z',z[bad_batches])



        updates, opt_state = optim.update(grads,opt_state,model)
        model = eqx.apply_updates(model, updates)
        return model, opt_state, loss_value
    train_losses = []
    
    for step, (t,x,y,z) in zip(range(steps), train_loader):
        model, opt_state, train_loss = make_step(model, opt_state, t,x,y,z)
        train_losses.append(train_loss)
        if jnp.isnan(train_loss):
            print("GOT A NAN AT STEP",step)
            break
        if (step % print_every) == 0 or (step == steps - 1):
            testloader = get_testloader()
            test_loss = evaluate_b(model, testloader)
            print("step=" + str(step) + " | train_loss=" + str(train_loss) + " | test_loss= "+ str(test_loss))

    return model,train_losses

# %%
lr_shifts = {
      100:0.2,
      1000:0.5,
      5000:0.1,
      10000:0.5,
      15000:0.5,
      20000:0.5
   }


schedule = optax.piecewise_constant_schedule(
   1e-2,lr_shifts
)


b_optim = optax.chain(
   optax.clip_by_global_norm(1e-5),
   optax.adam(schedule),
)
b_model = NeuralNetwork(jax.random.PRNGKey(420))
b_trainloader = get_trainloader(batch_size = 5000)

b_model,b_losses = train_b(b_model,b_optim,steps=40000,train_loader=b_trainloader,print_every=50)
# Out:
# step=0 | train_loss=2.7841272 | test_loss= -13.617403
# step=50 | train_loss=-30.601566 | test_loss= -30.24044
# step=100 | train_loss=-31.271442 | test_loss= -31.436436
# step=150 | train_loss=-31.688221 | test_loss= -31.598999
# step=200 | train_loss=-31.200294 | test_loss= -31.563522
# step=250 | train_loss=-31.248524 | test_loss= -31.641811
# [nan nan nan]
# Any nans predicted?
# False
# Loss value
# t [[0.]]
# x [[-2.2446394  -0.64164764]]
# y [[-7.9821186 -1.7217865]]
# z [[-1.2574993 -1.6917692]]
# GOT A NAN AT STEP 287

# %%
b_losses
# Out:
# [Array(2.7841272, dtype=float32),
#  Array(-13.822346, dtype=float32),
#  Array(-15.426292, dtype=float32),
#  Array(-7.5367737, dtype=float32),
#  Array(-11.392895, dtype=float32),
#  Array(-19.136929, dtype=float32),
#  Array(-24.422968, dtype=float32),
#  Array(-22.230913, dtype=float32),
#  Array(-22.275444, dtype=float32),
#  Array(-22.946507, dtype=float32),
#  Array(-25.540854, dtype=float32),
#  Array(-23.386898, dtype=float32),
#  Array(-25.037235, dtype=float32),
#  Array(-23.7486, dtype=float32),
#  Array(-22.654116, dtype=float32),
#  Array(-25.467012, dtype=float32),
#  Array(-25.067362, dtype=float32),
#  Array(-26.508394, dtype=float32),
#  Array(-26.079567, dtype=float32),
#  Array(-26.544024, dtype=float32),
#  Array(-27.232862, dtype=float32),
#  Array(-27.790674, dtype=float32),
#  Array(-27.372688, dtype=float32),
#  Array(-29.284372, dtype=float32),
#  Array(-29.07373, dtype=float32),
#  Array(-29.500328, dtype=float32),
#  Array(-29.402151, dtype=float32),
#  Array(-29.01279, dtype=float32),
#  Array(-29.649727, dtype=float32),
#  Array(-29.539299, dtype=float32),
#  Array(-29.094599, dtype=float32),
#  Array(-29.417295, dtype=float32),
#  Array(-30.052822, dtype=float32),
#  Array(-29.111233, dtype=float32),
#  Array(-29.42404, dtype=float32),
#  Array(-29.186731, dtype=float32),
#  Array(-30.721693, dtype=float32),
#  Array(-30.656406, dtype=float32),
#  Array(-30.305174, dtype=float32),
#  Array(-29.792461, dtype=float32),
#  Array(-28.932793, dtype=float32),
#  Array(-29.443832, dtype=float32),
#  Array(-31.243223, dtype=float32),
#  Array(-30.145615, dtype=float32),
#  Array(-28.8951, dtype=float32),
#  Array(-30.991657, dtype=float32),
#  Array(-30.355345, dtype=float32),
#  Array(-30.94938, dtype=float32),
#  Array(-31.172144, dtype=float32),
#  Array(-30.440166, dtype=float32),
#  Array(-30.6455, dtype=float32),
#  Array(-29.8903, dtype=float32),
#  Array(-30.368095, dtype=float32),
#  Array(-30.350372, dtype=float32),
#  Array(-31.07779, dtype=float32),
#  Array(-29.970621, dtype=float32),
#  Array(-29.270077, dtype=float32),
#  Array(-31.21156, dtype=float32),
#  Array(-31.222908, dtype=float32),
#  Array(-30.56924, dtype=float32),
#  Array(-31.225742, dtype=float32),
#  Array(-31.166872, dtype=float32),
#  Array(-29.813372, dtype=float32),
#  Array(-31.115507, dtype=float32),
#  Array(-30.386097, dtype=float32),
#  Array(-30.157974, dtype=float32),
#  Array(-31.968494, dtype=float32),
#  Array(-30.636091, dtype=float32),
#  Array(-30.893747, dtype=float32),
#  Array(-31.499155, dtype=float32),
#  Array(-31.624546, dtype=float32),
#  Array(-30.161812, dtype=float32),
#  Array(-30.052418, dtype=float32),
#  Array(-30.276901, dtype=float32),
#  Array(-30.733393, dtype=float32),
#  Array(-30.68058, dtype=float32),
#  Array(-30.230848, dtype=float32),
#  Array(-31.568398, dtype=float32),
#  Array(-30.33955, dtype=float32),
#  Array(-30.613024, dtype=float32),
#  Array(-32.391224, dtype=float32),
#  Array(-31.957096, dtype=float32),
#  Array(-32.50003, dtype=float32),
#  Array(-33.458244, dtype=float32),
#  Array(-31.22636, dtype=float32),
#  Array(-30.391659, dtype=float32),
#  Array(-31.401123, dtype=float32),
#  Array(-30.878668, dtype=float32),
#  Array(-30.10101, dtype=float32),
#  Array(-31.253357, dtype=float32),
#  Array(-30.010979, dtype=float32),
#  Array(-31.470371, dtype=float32),
#  Array(-31.762955, dtype=float32),
#  Array(-30.600885, dtype=float32),
#  Array(-31.087837, dtype=float32),
#  Array(-31.888794, dtype=float32),
#  Array(-31.086597, dtype=float32),
#  Array(-31.877058, dtype=float32),
#  Array(-30.966675, dtype=float32),
#  Array(-30.654358, dtype=float32),
#  Array(-30.960323, dtype=float32),
#  Array(-30.215988, dtype=float32),
#  Array(-31.424843, dtype=float32),
#  Array(-32.562088, dtype=float32),
#  Array(-31.944607, dtype=float32),
#  Array(-30.576756, dtype=float32),
#  Array(-32.13097, dtype=float32),
#  Array(-31.384212, dtype=float32),
#  Array(-31.689653, dtype=float32),
#  Array(-31.408161, dtype=float32),
#  Array(-31.088291, dtype=float32),
#  Array(-30.863907, dtype=float32),
#  Array(-31.314123, dtype=float32),
#  Array(-32.519566, dtype=float32),
#  Array(-31.60394, dtype=float32),
#  Array(-31.495422, dtype=float32),
#  Array(-31.526186, dtype=float32),
#  Array(-30.969444, dtype=float32),
#  Array(-31.944147, dtype=float32),
#  Array(-31.74688, dtype=float32),
#  Array(-31.460331, dtype=float32),
#  Array(-31.983452, dtype=float32),
#  Array(-31.040257, dtype=float32),
#  Array(-30.96812, dtype=float32),
#  Array(-31.645437, dtype=float32),
#  Array(-32.671333, dtype=float32),
#  Array(-30.43932, dtype=float32),
#  Array(-31.77423, dtype=float32),
#  Array(-31.590977, dtype=float32),
#  Array(-31.356674, dtype=float32),
#  Array(-32.163727, dtype=float32),
#  Array(-31.898746, dtype=float32),
#  Array(-32.42371, dtype=float32),
#  Array(-31.471592, dtype=float32),
#  Array(-35.51484, dtype=float32),
#  Array(-31.280699, dtype=float32),
#  Array(-32.119667, dtype=float32),
#  Array(-31.501373, dtype=float32),
#  Array(-32.228294, dtype=float32),
#  Array(-31.79604, dtype=float32),
#  Array(-29.962502, dtype=float32),
#  Array(-31.699554, dtype=float32),
#  Array(-31.652628, dtype=float32),
#  Array(-31.437098, dtype=float32),
#  Array(-31.539942, dtype=float32),
#  Array(-31.281235, dtype=float32),
#  Array(-32.343132, dtype=float32),
#  Array(-31.049778, dtype=float32),
#  Array(-31.433498, dtype=float32),
#  Array(-31.755249, dtype=float32),
#  Array(-31.669868, dtype=float32),
#  Array(-31.875591, dtype=float32),
#  Array(-31.190847, dtype=float32),
#  Array(-31.941204, dtype=float32),
#  Array(-31.004057, dtype=float32),
#  Array(-31.55763, dtype=float32),
#  Array(-31.575617, dtype=float32),
#  Array(-31.067144, dtype=float32),
#  Array(-31.569473, dtype=float32),
#  Array(-31.671677, dtype=float32),
#  Array(-32.172935, dtype=float32),
#  Array(-30.387304, dtype=float32),
#  Array(-32.051163, dtype=float32),
#  Array(-31.904907, dtype=float32),
#  Array(-31.438824, dtype=float32),
#  Array(-31.305206, dtype=float32),
#  Array(-32.77929, dtype=float32),
#  Array(-31.189793, dtype=float32),
#  Array(-31.966297, dtype=float32),
#  Array(-31.96453, dtype=float32),
#  Array(-31.060509, dtype=float32),
#  Array(-31.069382, dtype=float32),
#  Array(-31.273613, dtype=float32),
#  Array(-30.935486, dtype=float32),
#  Array(-31.512604, dtype=float32),
#  Array(-31.566221, dtype=float32),
#  Array(-31.307156, dtype=float32),
#  Array(-30.896854, dtype=float32),
#  Array(-32.411995, dtype=float32),
#  Array(-30.789394, dtype=float32),
#  Array(-31.164604, dtype=float32),
#  Array(-31.3252, dtype=float32),
#  Array(-31.655886, dtype=float32),
#  Array(-31.759394, dtype=float32),
#  Array(-31.152946, dtype=float32),
#  Array(-31.71976, dtype=float32),
#  Array(-31.15762, dtype=float32),
#  Array(-32.40602, dtype=float32),
#  Array(-32.626312, dtype=float32),
#  Array(-32.037666, dtype=float32),
#  Array(-31.032679, dtype=float32),
#  Array(-30.605703, dtype=float32),
#  Array(-31.054693, dtype=float32),
#  Array(-31.574623, dtype=float32),
#  Array(-31.999075, dtype=float32),
#  Array(-30.811907, dtype=float32),
#  Array(-31.525537, dtype=float32),
#  Array(-30.953306, dtype=float32),
#  Array(-31.983793, dtype=float32),
#  Array(-30.676119, dtype=float32),
#  Array(-31.182894, dtype=float32),
#  Array(-32.379654, dtype=float32),
#  Array(-31.690353, dtype=float32),
#  Array(-31.879017, dtype=float32),
#  Array(-30.817513, dtype=float32),
#  Array(-31.279331, dtype=float32),
#  Array(-31.905457, dtype=float32),
#  Array(-31.978542, dtype=float32),
#  Array(-30.88876, dtype=float32),
#  Array(-31.346022, dtype=float32),
#  Array(-31.168537, dtype=float32),
#  Array(-31.708792, dtype=float32),
#  Array(-30.252964, dtype=float32),
#  Array(-31.804337, dtype=float32),
#  Array(-30.812115, dtype=float32),
#  Array(-32.23668, dtype=float32),
#  Array(-31.65566, dtype=float32),
#  Array(-31.719698, dtype=float32),
#  Array(-32.36357, dtype=float32),
#  Array(-30.50249, dtype=float32),
#  Array(-31.201086, dtype=float32),
#  Array(-32.559082, dtype=float32),
#  Array(-30.678295, dtype=float32),
#  Array(-31.834763, dtype=float32),
#  Array(-31.70426, dtype=float32),
#  Array(-32.106136, dtype=float32),
#  Array(-30.950605, dtype=float32),
#  Array(-31.925068, dtype=float32),
#  Array(-30.343107, dtype=float32),
#  Array(-31.860622, dtype=float32),
#  Array(-32.39998, dtype=float32),
#  Array(-30.638878, dtype=float32),
#  Array(-31.080563, dtype=float32),
#  Array(-30.773247, dtype=float32),
#  Array(-32.92984, dtype=float32),
#  Array(-31.738197, dtype=float32),
#  Array(-30.938633, dtype=float32),
#  Array(-31.686787, dtype=float32),
#  Array(-31.525795, dtype=float32),
#  Array(-31.649052, dtype=float32),
#  Array(-31.662115, dtype=float32),
#  Array(-32.280518, dtype=float32),
#  Array(-31.01126, dtype=float32),
#  Array(-31.527954, dtype=float32),
#  Array(-31.889874, dtype=float32),
#  Array(-31.307018, dtype=float32),
#  Array(-31.087364, dtype=float32),
#  Array(-31.889206, dtype=float32),
#  Array(-31.617104, dtype=float32),
#  Array(-31.130291, dtype=float32),
#  Array(-31.23415, dtype=float32),
#  Array(-39.75747, dtype=float32),
#  Array(-30.930248, dtype=float32),
#  Array(-31.909836, dtype=float32),
#  Array(-31.729233, dtype=float32),
#  Array(-31.887362, dtype=float32),
#  Array(-30.770256, dtype=float32),
#  Array(-32.369705, dtype=float32),
#  Array(-31.822746, dtype=float32),
#  Array(-31.250843, dtype=float32),
#  Array(-32.0308, dtype=float32),
#  Array(-31.47232, dtype=float32),
#  Array(-31.054977, dtype=float32),
#  Array(-31.68298, dtype=float32),
#  Array(-31.361673, dtype=float32),
#  Array(-31.986063, dtype=float32),
#  Array(-31.391037, dtype=float32),
#  Array(-31.592072, dtype=float32),
#  Array(-31.87234, dtype=float32),
#  Array(-31.156532, dtype=float32),
#  Array(-32.054035, dtype=float32),
#  Array(-31.056965, dtype=float32),
#  Array(-31.845926, dtype=float32),
#  Array(-31.645872, dtype=float32),
#  Array(-31.934425, dtype=float32),
#  Array(-31.26704, dtype=float32),
#  Array(-30.521816, dtype=float32),
#  Array(-31.826311, dtype=float32),
#  Array(-31.285732, dtype=float32),
#  Array(-31.5802, dtype=float32),
#  Array(-31.354994, dtype=float32),
#  Array(-31.809906, dtype=float32),
#  Array(-30.416876, dtype=float32),
#  Array(-31.47413, dtype=float32),
#  Array(-31.565645, dtype=float32),
#  Array(-31.670826, dtype=float32),
#  Array(-31.311455, dtype=float32),
#  Array(nan, dtype=float32)]

# %%
lr_shifts = {
      1000:0.5,
      5000:0.1,
      10000:0.5,
      15000:0.5,
      20000:0.5
   }


schedule = optax.piecewise_constant_schedule(
   1e-3,lr_shifts
)


eta_optim = optax.chain(
   optax.adam(schedule),
)

eta_trainloader = get_trainloader(batch_size = 128)

eta_model = NeuralNetwork(jax.random.PRNGKey(420))
eta_model,eta_losses = train_eta(eta_model,eta_optim,steps=40000,train_loader=eta_trainloader,print_every=5000)
# Out:
# step=0 | train_loss=2.1169572 | test_loss= 168.41092
# step=5000 | train_loss=-0.2771662 | test_loss= -0.24497792
# step=10000 | train_loss=-0.1894488 | test_loss= -0.25749892
# step=15000 | train_loss=-0.2875368 | test_loss= -0.25891697
# step=20000 | train_loss=-0.31756464 | test_loss= -0.26018253
# step=25000 | train_loss=-0.22100097 | test_loss= -0.2607611
# step=30000 | train_loss=-0.21786687 | test_loss= -0.260921
# step=35000 | train_loss=-0.15470698 | test_loss= -0.26089966
# step=39999 | train_loss=-0.37241423 | test_loss= -0.26106775

# %%
eps = 0.2
epsilon = lambda t: t*(1-t)*eps 

vmapped_b_model = vmap(b_model)
vmapped_eta_model = vmap(eta_model)
def dX_t(t,x,args):
    t_vec = jnp.ones((len(x),1))*t
    return vmapped_b_model(jnp.hstack([t_vec,x])) - (epsilon(t)/(gamma(t)+1e-12))*vmapped_eta_model(jnp.hstack([t_vec,x]))



t0, t1 = 0.0, 1.0
# t_vec = jnp.ones((len(x),1))*t
# drift = lambda t, x, args: dX_t(t,x)
diffusion = lambda t, x, args: 2*jnp.sqrt(2*epsilon(t))
brownian_motion = VirtualBrownianTree(t0, t1, tol=1e-3, shape=(), key=jax.random.PRNGKey(1))
terms = MultiTerm(ODETerm(dX_t), ControlTerm(diffusion, brownian_motion))
solver = Heun()
saveat = SaveAt(dense=True)

sol = diffeqsolve(terms, solver, t0, t1, dt0=0.005, y0=reference_samples.copy(), saveat=saveat)
X = sol.evaluate(1.0)
print(X)
# Out:
# [[-2.9172425  4.6288447]
#  [ 6.370421  -3.7894776]
#  [-4.539945  -4.9516544]
#  ...
#  [ 5.46829    2.995855 ]
#  [ 3.628797   5.802954 ]
#  [ 3.670683   5.3677754]]

# %%
plt.scatter(X[:,0],X[:,1])

# %%
plt.scatter(X[:,0],X[:,1],c='red',alpha = 0.2)

# %% [markdown]
# # Make pretty flow plots later

# %%
X_hist = jnp.array(X_hist)
plt.scatter(X0[:,0],X0[:,1],c='red',alpha = 0.5)
plt.scatter(X[:,0],X[:,1],c='black',alpha = 0.5)

for i in range(500):
    plt.plot(X_hist[:,i,0],X_hist[:,i,1],c='blue',alpha = 0.05,lw = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [120], in <cell line: 1>()
# ----> 1 X_hist = jnp.array(X_hist)
#       2 plt.scatter(X0[:,0],X0[:,1],c='red',alpha = 0.5)
#       3 plt.scatter(X[:,0],X[:,1],c='black',alpha = 0.5)
#
# NameError: name 'X_hist' is not defined

# %%
term = ODETerm(dX_t)
solver = Dopri5()
X0 = reference_samples
solution = diffeqsolve(term, solver, t0=0, t1=1., dt0=0.01, y0=X0)
